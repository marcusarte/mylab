# %%
pip install Pandas
# Out:
# Collecting Pandas
#   Downloading https://files.pythonhosted.org/packages/63/e0/a1b39cdcb2c391f087a1538bc8a6d62a82d0439693192aef541d7b123769/pandas-0.25.3-cp37-cp37m-manylinux1_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 3.4MB/s eta 0:00:01    |████████                        | 2.6MB 3.4MB/s eta 0:00:03     |█████████████████▉              | 5.8MB 3.4MB/s eta 0:00:02     |██████████████████████▋         | 7.4MB 3.4MB/s eta 0:00:01
# Collecting pytz>=2017.2 (from Pandas)
#   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
#      |████████████████████████████████| 512kB 52.2MB/s eta 0:00:01
# Collecting numpy>=1.13.3 (from Pandas)
#   Downloading https://files.pythonhosted.org/packages/00/4a/e34fce8f18c0e052c2b49f1b3713469d855f7662d58ae2b82a88341e865b/numpy-1.17.3-cp37-cp37m-manylinux1_x86_64.whl (20.0MB)
#      |████████████████████████████████| 20.0MB 27.1MB/s eta 0:00:01    |████████████                    | 7.4MB 27.1MB/s eta 0:00:01     |██████████████▌                 | 9.0MB 27.1MB/s eta 0:00:01     |███████████████████▏            | 12.0MB 27.1MB/s eta 0:00:01     |███████████████████████▎        | 14.6MB 27.1MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from Pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.6.1->Pandas) (1.12.0)
# Installing collected packages: pytz, numpy, Pandas
# Successfully installed Pandas-0.25.3 numpy-1.17.3 pytz-2019.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/b0/16/63576a1a001752e34bf8ea62e367997530dc553b689356b9879339cf45a4/xlrd-1.2.0-py2.py3-none-any.whl (103kB)
#      |████████████████████████████████| 112kB 3.2MB/s eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
amb_cmdb = pd.read_excel("cmdb.xlsx")

# %%
amb_cmdb.head()
# Out:
#   Cliente                                    Nome do Serviço Sigla do Serviço  \
# 0    INSS  Serviço de Hosting - Agência Nacional Transpor...     HOSTING-ANTT
# 1    INSS  Serviço de Hosting - Agência Nacional Transpor...     HOSTING-ANTT
# 2    INSS       Sistema Nacional de Controle de Medicamentos             SNCM
# 3    INSS       Sistema Nacional de Controle de Medicamentos             SNCM
# 4    INSS       Sistema Nacional de Controle de Medicamentos             SNCM
#
#   ID do IC Alternativo (Ambiente)         Ambiente  \
# 0                 (P)HOSTING-ANTT         Produção
# 1                 (P)HOSTING-ANTT         Produção
# 2                         (D)SNCM  Desenvolvimento
# 3                         (D)SNCM  Desenvolvimento
# 4                         (H)SNCM      Homologação
#
#                        Função                           Servidor    Classe  \
# 0                     Hosting                       HN200070.dmz  Servidor
# 1                     Hosting                           HN200076  Servidor
# 2  Servidor de Banco de Dados       e1112dbadm05.exadata.prevnet  Servidor
# 3  Servidor de Banco de Dados  e1112dbadm05vmd01.exadata.prevnet  Servidor
# 4                      Apache                   v331h057.prevnet  Servidor
#
#   DC Gestor              Status Symbol
# 0      DCDF                 Em serviço
# 1      DCDF  Aguardando desmobilização
# 2      DCRJ                 Em serviço
# 3      DCRJ                 Em serviço
# 4      DCSP                 Em serviço

# %%
amb_cmdb[["Cliente", "Ambiente", "Função"]].head()
# Out:
#   Cliente         Ambiente                      Função
# 0    INSS         Produção                     Hosting
# 1    INSS         Produção                     Hosting
# 2    INSS  Desenvolvimento  Servidor de Banco de Dados
# 3    INSS  Desenvolvimento  Servidor de Banco de Dados
# 4    INSS      Homologação                      Apache

# %%
amb_cmdb.loc[0]
# Out:
# Cliente                                                                         INSS
# Nome do Serviço                    Serviço de Hosting - Agência Nacional Transpor...
# Sigla do Serviço                                                        HOSTING-ANTT
# ID do IC Alternativo (Ambiente)                                      (P)HOSTING-ANTT
# Ambiente                                                                    Produção
# Função                                                                       Hosting
# Servidor                                                                HN200070.dmz
# Classe                                                                      Servidor
# DC Gestor                                                                       DCDF
# Status Symbol                                                             Em serviço
# Name: 0, dtype: object

# %%
amb_cmdb
# Out:
#       Cliente                                    Nome do Serviço  \
# 0        INSS  Serviço de Hosting - Agência Nacional Transpor...
# 1        INSS  Serviço de Hosting - Agência Nacional Transpor...
# 2        INSS       Sistema Nacional de Controle de Medicamentos
# 3        INSS       Sistema Nacional de Controle de Medicamentos
# 4        INSS       Sistema Nacional de Controle de Medicamentos
# ...       ...                                                ...
# 20010    INSS  Sistema de Cobrança Administrativa - Manutençã...
# 20011    INSS  Sistema de Cobrança Administrativa - Manutençã...
# 20012    INSS  Sistema de Cobrança Administrativa - Manutençã...
# 20013    INSS  Sistema de Cobrança Administrativa - Manutençã...
# 20014    INSS  Sistema de Cobrança Administrativa - Manutençã...
#
#            Sigla do Serviço ID do IC Alternativo (Ambiente)         Ambiente  \
# 0              HOSTING-ANTT                 (P)HOSTING-ANTT         Produção
# 1              HOSTING-ANTT                 (P)HOSTING-ANTT         Produção
# 2                      SNCM                         (D)SNCM  Desenvolvimento
# 3                      SNCM                         (D)SNCM  Desenvolvimento
# 4                      SNCM                         (H)SNCM      Homologação
# ...                     ...                             ...              ...
# 20010  SICOB-MANUT-MIGRACAO         (P)SICOB-MANUT-MIGRACAO         Produção
# 20011  SICOB-MANUT-MIGRACAO         (P)SICOB-MANUT-MIGRACAO         Produção
# 20012  SICOB-MANUT-MIGRACAO         (P)SICOB-MANUT-MIGRACAO         Produção
# 20013  SICOB-MANUT-MIGRACAO         (P)SICOB-MANUT-MIGRACAO         Produção
# 20014  SICOB-MANUT-MIGRACAO         (P)SICOB-MANUT-MIGRACAO         Produção
#
#                            Função                           Servidor  \
# 0                         Hosting                       HN200070.dmz
# 1                         Hosting                           HN200076
# 2      Servidor de Banco de Dados       e1112dbadm05.exadata.prevnet
# 3      Servidor de Banco de Dados  e1112dbadm05vmd01.exadata.prevnet
# 4                          Apache                   v331h057.prevnet
# ...                           ...                                ...
# 20010                      Apache                   v331p121.prevnet
# 20011                      Apache                   v331p122.prevnet
# 20012                   Aplicação                   v321p670.prevnet
# 20013                   Aplicação                   v321p673.prevnet
# 20014                   Aplicação                   v321p674.prevnet
#
#          Classe DC Gestor              Status Symbol
# 0      Servidor      DCDF                 Em serviço
# 1      Servidor      DCDF  Aguardando desmobilização
# 2      Servidor      DCRJ                 Em serviço
# 3      Servidor      DCRJ                 Em serviço
# 4      Servidor      DCSP                 Em serviço
# ...         ...       ...                        ...
# 20010  Servidor      DCSP                 Em serviço
# 20011  Servidor      DCSP                 Em serviço
# 20012  Servidor      DCSP                 Em serviço
# 20013  Servidor      DCSP                 Em serviço
# 20014  Servidor      DCSP                 Em serviço
#
# [20015 rows x 10 columns]

# %%
cli_ins = amb_cmdb.Cliente == "INSS"

# %%
cli_ins.head
# Out:
# <bound method NDFrame.head of 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 20010    True
# 20011    True
# 20012    True
# 20013    True
# 20014    True
# Name: Cliente, Length: 20015, dtype: bool>

# %%
amb_cmdb[cli_ins].head() #Filtro da Series Cliente
# Out:
#   Cliente                                    Nome do Serviço Sigla do Serviço  \
# 0    INSS  Serviço de Hosting - Agência Nacional Transpor...     HOSTING-ANTT
# 1    INSS  Serviço de Hosting - Agência Nacional Transpor...     HOSTING-ANTT
# 2    INSS       Sistema Nacional de Controle de Medicamentos             SNCM
# 3    INSS       Sistema Nacional de Controle de Medicamentos             SNCM
# 4    INSS       Sistema Nacional de Controle de Medicamentos             SNCM
#
#   ID do IC Alternativo (Ambiente)         Ambiente  \
# 0                 (P)HOSTING-ANTT         Produção
# 1                 (P)HOSTING-ANTT         Produção
# 2                         (D)SNCM  Desenvolvimento
# 3                         (D)SNCM  Desenvolvimento
# 4                         (H)SNCM      Homologação
#
#                        Função                           Servidor    Classe  \
# 0                     Hosting                       HN200070.dmz  Servidor
# 1                     Hosting                           HN200076  Servidor
# 2  Servidor de Banco de Dados       e1112dbadm05.exadata.prevnet  Servidor
# 3  Servidor de Banco de Dados  e1112dbadm05vmd01.exadata.prevnet  Servidor
# 4                      Apache                   v331h057.prevnet  Servidor
#
#   DC Gestor              Status Symbol
# 0      DCDF                 Em serviço
# 1      DCDF  Aguardando desmobilização
# 2      DCRJ                 Em serviço
# 3      DCRJ                 Em serviço
# 4      DCSP                 Em serviço

# %%
amb_cmdb[cli_ins].count()
# Out:
# Cliente                            20015
# Nome do Serviço                    20015
# Sigla do Serviço                   20015
# ID do IC Alternativo (Ambiente)    20015
# Ambiente                           20015
# Função                             19875
# Servidor                           20015
# Classe                             20015
# DC Gestor                          20015
# Status Symbol                      20015
# dtype: int64

# %%
amb_cmdb.Cliente.head()
# Out:
# 0    INSS
# 1    INSS
# 2    INSS
# 3    INSS
# 4    INSS
# Name: Cliente, dtype: object

# %%
amb_prod = amb_cmdb.Ambiente == 'Produção'

# %%
type(amb_prod)
# Out:
# pandas.core.series.Series

# %%
amb_cmdb[amb_prod].head()
# Out:
#    Cliente                                    Nome do Serviço  \
# 0     INSS  Serviço de Hosting - Agência Nacional Transpor...
# 1     INSS  Serviço de Hosting - Agência Nacional Transpor...
# 30    INSS       Sistema Nacional de Controle de Medicamentos
# 31    INSS       Sistema Nacional de Controle de Medicamentos
# 32    INSS       Sistema Nacional de Controle de Medicamentos
#
#    Sigla do Serviço ID do IC Alternativo (Ambiente)  Ambiente     Função  \
# 0      HOSTING-ANTT                 (P)HOSTING-ANTT  Produção    Hosting
# 1      HOSTING-ANTT                 (P)HOSTING-ANTT  Produção    Hosting
# 30             SNCM                         (P)SNCM  Produção  Aplicação
# 31             SNCM                         (P)SNCM  Produção  Aplicação
# 32             SNCM                         (P)SNCM  Produção  Aplicação
#
#             Servidor    Classe DC Gestor              Status Symbol
# 0       HN200070.dmz  Servidor      DCDF                 Em serviço
# 1           HN200076  Servidor      DCDF  Aguardando desmobilização
# 30  v321p487.prevnet  Servidor      DCSP              Em requisição
# 31  v321p488.prevnet  Servidor      DCSP              Em requisição
# 32  v321p489.prevnet  Servidor      DCSP              Em requisição
